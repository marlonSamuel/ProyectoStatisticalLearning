# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import svm
import global_funcs

# %%
X_train = pd.read_csv('X_train.csv')
Y_train = pd.read_csv('Y_train.csv')
X_valid = pd.read_csv('X_valid.csv')
Y_valid = pd.read_csv('Y_valid.csv')

# %%
def train(X,Y,X_test,Y_test,kernel,cv=None,deg=1):
    conf_string = 'svc, kernel: '+kernel+' class_weitht: '+str(cv)+("degree: "+str(deg) if deg > 1 else "")
    clf = svm.SVC(kernel=kernel,class_weight=cv,degree=deg)
    clf.fit(X_train, Y_train.values.ravel())
    y_pred_test = clf.predict(X_test)
    y_pred_train = clf.predict(X)
    report = global_funcs.getReport(Y_test["passenger_survived"],Y["passenger_survived"],y_pred_test, y_pred_train)
    df_report = pd.DataFrame(report)
    
    return {
        "clf":clf,
        "reporte":df_report,
        "conf_string":conf_string
    }

# %%
kernels = ['rbf','linear','poly','sigmoid']
degrees = [2,3,4,5]
class_weights = [None,'balanced']

modelos = []

for k in kernels:
    for c in class_weights:
        if k == 'poly':
            for d in degrees:
                modelo = train(X_train,Y_train,X_valid,Y_valid,k,c,d)#entrenando el modelo
                global_funcs.writeInExcel(modelo['reporte'],"bitacora_svc.xlsx",modelo['conf_string'])#escribiendo en bitacora excel
                modelo["reporte"]
                modelos.append({
                    "accuracy": modelo["reporte"].iloc[0]["metrics_test"],
                    "presicion":modelo["reporte"].iloc[1]["metrics_test"],
                    "recall": modelo["reporte"].iloc[2]["metrics_test"],
                    "f1_score": modelo["reporte"].iloc[3]["metrics_test"],
                    "kernel":k,
                    "class_weith":c,
                    "degree ":d})
        modelo = train(X_train,Y_train,X_valid,Y_valid,k,c)#entrenando el modelo
        global_funcs.writeInExcel(modelo['reporte'],"bitacora_svc.xlsx",modelo['conf_string'])#escribiendo en bitacora excel
        modelo["reporte"]
        modelos.append({
                    "accuracy": modelo["reporte"].iloc[0]["metrics_test"],
                    "presicion":modelo["reporte"].iloc[1]["metrics_test"],
                    "recall": modelo["reporte"].iloc[2]["metrics_test"],
                    "f1_score": modelo["reporte"].iloc[3]["metrics_test"],
                    "kernel":k,
                    "class_weith":c})
# Out:
# verdaderos positivos: 36
# falsos positivos: 8
# verdaderos negativos: 83
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87        91
#            1       0.82      0.69      0.75        52
#
#     accuracy                           0.83       143
#    macro avg       0.83      0.80      0.81       143
# weighted avg       0.83      0.83      0.83       143
# verdaderos positivos: 36
# falsos positivos: 11
# verdaderos negativos: 80
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86        91
#            1       0.77      0.69      0.73        52
#
#     accuracy                           0.81       143
#    macro avg       0.80      0.79      0.79       143
# weighted avg       0.81      0.81      0.81       143
# verdaderos positivos: 39
# falsos positivos: 12
# verdaderos negativos: 79
# falsos negativos: 13
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86        91
#            1       0.76      0.75      0.76        52
#
#     accuracy                           0.83       143
#    macro avg       0.81      0.81      0.81       143
# weighted avg       0.82      0.83      0.82       143
# verdaderos positivos: 39
# falsos positivos: 12
# verdaderos negativos: 79
# falsos negativos: 13
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86        91
#            1       0.76      0.75      0.76        52
#
#     accuracy                           0.83       143
#    macro avg       0.81      0.81      0.81       143
# weighted avg       0.82      0.83      0.82       143
# verdaderos positivos: 36
# falsos positivos: 8
# verdaderos negativos: 83
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87        91
#            1       0.82      0.69      0.75        52
#
#     accuracy                           0.83       143
#    macro avg       0.83      0.80      0.81       143
# weighted avg       0.83      0.83      0.83       143
# verdaderos positivos: 36
# falsos positivos: 9
# verdaderos negativos: 82
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        91
#            1       0.80      0.69      0.74        52
#
#     accuracy                           0.83       143
#    macro avg       0.82      0.80      0.80       143
# weighted avg       0.82      0.83      0.82       143
# verdaderos positivos: 36
# falsos positivos: 8
# verdaderos negativos: 83
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87        91
#            1       0.82      0.69      0.75        52
#
#     accuracy                           0.83       143
#    macro avg       0.83      0.80      0.81       143
# weighted avg       0.83      0.83      0.83       143
# verdaderos positivos: 36
# falsos positivos: 8
# verdaderos negativos: 83
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87        91
#            1       0.82      0.69      0.75        52
#
#     accuracy                           0.83       143
#    macro avg       0.83      0.80      0.81       143
# weighted avg       0.83      0.83      0.83       143
# verdaderos positivos: 39
# falsos positivos: 12
# verdaderos negativos: 79
# falsos negativos: 13
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86        91
#            1       0.76      0.75      0.76        52
#
#     accuracy                           0.83       143
#    macro avg       0.81      0.81      0.81       143
# weighted avg       0.82      0.83      0.82       143
# verdaderos positivos: 39
# falsos positivos: 14
# verdaderos negativos: 77
# falsos negativos: 13
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.85        91
#            1       0.74      0.75      0.74        52
#
#     accuracy                           0.81       143
#    macro avg       0.80      0.80      0.80       143
# weighted avg       0.81      0.81      0.81       143
# verdaderos positivos: 36
# falsos positivos: 11
# verdaderos negativos: 80
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86        91
#            1       0.77      0.69      0.73        52
#
#     accuracy                           0.81       143
#    macro avg       0.80      0.79      0.79       143
# weighted avg       0.81      0.81      0.81       143
# verdaderos positivos: 36
# falsos positivos: 15
# verdaderos negativos: 76
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        91
#            1       0.71      0.69      0.70        52
#
#     accuracy                           0.78       143
#    macro avg       0.77      0.76      0.76       143
# weighted avg       0.78      0.78      0.78       143
# verdaderos positivos: 36
# falsos positivos: 15
# verdaderos negativos: 76
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        91
#            1       0.71      0.69      0.70        52
#
#     accuracy                           0.78       143
#    macro avg       0.77      0.76      0.76       143
# weighted avg       0.78      0.78      0.78       143
# verdaderos positivos: 39
# falsos positivos: 12
# verdaderos negativos: 79
# falsos negativos: 13
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86        91
#            1       0.76      0.75      0.76        52
#
#     accuracy                           0.83       143
#    macro avg       0.81      0.81      0.81       143
# weighted avg       0.82      0.83      0.82       143
# verdaderos positivos: 32
# falsos positivos: 28
# verdaderos negativos: 63
# falsos negativos: 20
#               precision    recall  f1-score   support
#
#            0       0.76      0.69      0.72        91
#            1       0.53      0.62      0.57        52
#
#     accuracy                           0.66       143
#    macro avg       0.65      0.65      0.65       143
# weighted avg       0.68      0.66      0.67       143
# verdaderos positivos: 36
# falsos positivos: 20
# verdaderos negativos: 71
# falsos negativos: 16
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80        91
#            1       0.64      0.69      0.67        52
#
#     accuracy                           0.75       143
#    macro avg       0.73      0.74      0.73       143
# weighted avg       0.75      0.75      0.75       143

# %%
#resumen de modelos
resumen = pd.DataFrame(modelos)
resumen
# Out:
#     accuracy  presicion    recall  f1_score   kernel class_weith  degree
# 0   0.832168   0.818182  0.692308  0.750000      rbf        None      NaN
# 1   0.811189   0.765957  0.692308  0.727273      rbf    balanced      NaN
# 2   0.825175   0.764706  0.750000  0.757282   linear        None      NaN
# 3   0.825175   0.764706  0.750000  0.757282   linear    balanced      NaN
# 4   0.832168   0.818182  0.692308  0.750000     poly        None      2.0
# 5   0.825175   0.800000  0.692308  0.742268     poly        None      3.0
# 6   0.832168   0.818182  0.692308  0.750000     poly        None      4.0
# 7   0.832168   0.818182  0.692308  0.750000     poly        None      5.0
# 8   0.825175   0.764706  0.750000  0.757282     poly        None      NaN
# 9   0.811189   0.735849  0.750000  0.742857     poly    balanced      2.0
# 10  0.811189   0.765957  0.692308  0.727273     poly    balanced      3.0
# 11  0.783217   0.705882  0.692308  0.699029     poly    balanced      4.0
# 12  0.783217   0.705882  0.692308  0.699029     poly    balanced      5.0
# 13  0.825175   0.764706  0.750000  0.757282     poly    balanced      NaN
# 14  0.664336   0.533333  0.615385  0.571429  sigmoid        None      NaN
# 15  0.748252   0.642857  0.692308  0.666667  sigmoid    balanced      NaN
